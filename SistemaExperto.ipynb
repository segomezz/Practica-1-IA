# %%
import collections.abc
if not hasattr(collections, 'Mapping'):
    collections.Mapping = collections.abc.Mapping

# %% [markdown]
# # Sistema Experto (experta)
#
# Definir clases de Hechos: Se deben definir al menos unas 5 clases de hechos

# %%
from experta import * # Nos traemos todo desde experta

# Hay que cambiar el nombre de los siguientes 5 hechos cuando tengamos más información del sistema de Lógica Difusa y las Ontologías

class PrimerHecho(Fact):
    """Info primer hecho"""
    pass

class SegundoHecho(Fact):
    """Info segundo hecho"""
    pass

class TercerHecho(Fact):
    """Info tercer hecho"""
    pass

class CuartoHecho(Fact):
    """Info cuarto hecho"""
    pass

class QuintoHecho(Fact):
    """Info quinto hecho"""
    pass

# %% [markdown]
# Definir reglas basadas en el conocimiento del dominio:
#
#     -  Se deben definir al menos 15 reglas que hagan uso de las clases de
#     hechos anteriormente definidas y sus instancias.
#     -  Utilizar prioridades y las técnicas de control de ejecución así:
#         - Utilizar al menos 3 niveles de prioridad.
#         - Utilizar 2 casos de usos de control de ejecución
#         - Implementar al menos un mecanismo para evitar conflictos entre
#           reglas o bucles infinitos.

# %%
# Al menos 3 reglas deben tener diferentes niveles de prioridad (saliencie=1). Entre más alta sea la prioridad más rápido se va a ejecutar.
# Ejemplo: Regla 1 tiene un salience 2 y Regla 2 tiene un salience 1. La primera en ejecutarse será salience 2 o sea la regla 1.

# Preguntar en asesoría: usos de control en ejecución

# El mecanismo para evitar conflictos entre reglas o bucles infinitos lo haremos con retract() y declare()
# Recordemos que retract() elimina hechos de la memoria de trabajo del sistema experto -> 2-06 de collab
# Recordemos que declare() define dinámicamente nuevos hechos o clases de hechos durante la ejecución del programa -> 2-05 de collab
# Estaría bien preguntar en asesoría qué pasa si se declara un nuevo hecho (estado) sin retractarlo (aunque creo que ya sé la respuesta: existirán dos estados)


class InvestmentRuleEngine(KnowledgeEngine):
    @Rule(PrimerHecho(name="prueba"))
    def accion_uno(self):
        print("printear lo que hará esta acción")

    @Rule(PrimerHecho(name="prueba"))
    def accion_dos(self):
        print("printear lo que hará esta acción")

    @Rule(PrimerHecho(name="prueba"))
    def accion_tres(self):
        print("printear lo que hará esta acción")
        
    @Rule(PrimerHecho(name="prueba"))
    def accion_cuatro(self):
        print("printear lo que hará esta acción")

    @Rule(PrimerHecho(name="prueba"))
    def accion_cinco(self):
        print("printear lo que hará esta acción")
        
    @Rule(PrimerHecho(name="prueba"))
    def accion_seis(self):
        print("printear lo que hará esta acción")

    @Rule(PrimerHecho(name="prueba"))
    def accion_siete(self):
        print("printear lo que hará esta acción")
        
    @Rule(PrimerHecho(name="prueba"))
    def accion_ocho(self):
        print("printear lo que hará esta acción")

    @Rule(PrimerHecho(name="prueba"))
    def accion_nueve(self):
        print("printear lo que hará esta acción")
        
    @Rule(PrimerHecho(name="prueba"))
    def accion_diez(self):
        print("printear lo que hará esta acción")
  
    @Rule(PrimerHecho(name="prueba"))
    def accion_once(self):
        print("printear lo que hará esta acción")
        
    @Rule(PrimerHecho(name="prueba"))
    def accion_doce(self):
        print("printear lo que hará esta acción")

    @Rule(PrimerHecho(name="prueba"))
    def accion_trece(self):
        print("printear lo que hará esta acción")
        
    @Rule(PrimerHecho(name="prueba"))
    def accion_catorce(self):
        print("printear lo que hará esta acción")

    @Rule(PrimerHecho(name="prueba"))
    def accion_quince(self):
        print("printear lo que hará esta acción")
        
    @Rule(PrimerHecho(name="prueba"))
    def accion_dieciseis(self):
        print("printear lo que hará esta acción")

# %% [markdown]
# Definir la base de hechos:
#
#     - Definir mínimo 40 hechos

# %%
engine = InvestmentRuleEngine()
engine.reset()

engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")

engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")

engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")

engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")
engine.declare("""Acá irán los hechos""")

engine.run()

# Preguntar en asesoría si definir mínimo 40 hechos se refieren al engine.declare o a otra cosa
